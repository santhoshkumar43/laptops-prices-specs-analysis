# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumar43/laptops-prices-specs-analysis/blob/main/laptop_prices_and_specs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA - LAPTOP PRICES AND SPECS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = pd.read_csv("Cleaned_Laptop_data.csv")

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            896 non-null    object
#  1   model            896 non-null    object
#  2   processor_brand  896 non-null    object
#  3   processor_name   896 non-null    object
#  4   processor_gnrtn  896 non-null    object
#  5   ram_gb           896 non-null    object
#  6   ram_type         896 non-null    object
#  7   ssd              896 non-null    object
#  8   hdd              896 non-null    object
#  9   os               896 non-null    object
#  10  os_bit           896 non-null    object
#  11  graphic_card_gb  896 non-null    int64
#  12  weight           896 non-null    object
#  13  display_size     896 non-null    object
#  14  warranty         896 non-null    int64
#  15  Touchscreen      896 non-null    object
#  16  msoffice         896 non-null    object
# ...

# %%
file
# Out:
#        brand     model processor_brand     processor_name processor_gnrtn  \
# 0     Lenovo   A6-9225             AMD  A6-9225 Processor            10th
# 1     Lenovo   Ideapad             AMD           APU Dual            10th
# 2      Avita      PURA             AMD           APU Dual            10th
# 3      Avita      PURA             AMD           APU Dual            10th
# 4      Avita      PURA             AMD           APU Dual            10th
# ..       ...       ...             ...                ...             ...
# 891     ASUS       ROG             AMD            Ryzen 9         Missing
# 892     ASUS     Ryzen             AMD            Ryzen 9         Missing
# 893     ASUS     Ryzen             AMD            Ryzen 9         Missing
# 894  SAMSUNG    Galaxy        Qualcomm      Snapdragon 7c         Missing
# 895   Lenovo  Thinkpad             AMD            Ryzen 5            10th
#
#       ram_gb ram_type      ssd      hdd       os  ... display_size  warranty  \
# ...

# %%
file.head()
# Out:
#     brand    model processor_brand     processor_name processor_gnrtn  \
# 0  Lenovo  A6-9225             AMD  A6-9225 Processor            10th
# 1  Lenovo  Ideapad             AMD           APU Dual            10th
# 2   Avita     PURA             AMD           APU Dual            10th
# 3   Avita     PURA             AMD           APU Dual            10th
# 4   Avita     PURA             AMD           APU Dual            10th
#
#     ram_gb ram_type     ssd      hdd       os  ... display_size  warranty  \
# 0  4 GB GB     DDR4    0 GB  1024 GB  Windows  ...      Missing         0
# 1  4 GB GB     DDR4    0 GB   512 GB  Windows  ...      Missing         0
# 2  4 GB GB     DDR4  128 GB     0 GB  Windows  ...      Missing         0
# 3  4 GB GB     DDR4  128 GB     0 GB  Windows  ...      Missing         0
# 4  4 GB GB     DDR4  256 GB     0 GB  Windows  ...      Missing         0
#
#   Touchscreen msoffice  latest_price old_price discount  star_rating  ratings  \
# ...

# %%
file.tail()
# Out:
#        brand     model processor_brand processor_name processor_gnrtn  \
# 891     ASUS       ROG             AMD        Ryzen 9         Missing
# 892     ASUS     Ryzen             AMD        Ryzen 9         Missing
# 893     ASUS     Ryzen             AMD        Ryzen 9         Missing
# 894  SAMSUNG    Galaxy        Qualcomm  Snapdragon 7c         Missing
# 895   Lenovo  Thinkpad             AMD        Ryzen 5            10th
#
#       ram_gb ram_type      ssd     hdd       os  ... display_size  warranty  \
# 891  4 GB GB     DDR4  1024 GB    0 GB  Windows  ...           16         1
# 892  4 GB GB     DDR4  1024 GB    0 GB  Windows  ...      Missing         1
# 893  4 GB GB     DDR4  1024 GB    0 GB  Windows  ...           16         1
# 894  4 GB GB  LPDDR4X     0 GB  512 GB  Windows  ...      Missing         0
# 895  8 GB GB     DDR4   512 GB    0 GB      DOS  ...           14         0
#
#     Touchscreen msoffice  latest_price old_price discount  star_rating  \
# ...

# %%
file.describe()
# Out:
#        graphic_card_gb    warranty   latest_price      old_price    discount  \
# count       896.000000  896.000000     896.000000     896.000000  896.000000
# mean          1.198661    0.691964   76309.860491   88134.154018   18.527902
# std           2.057454    0.606282   46613.354368   55719.645554   10.508486
# min           0.000000    0.000000   13990.000000       0.000000    0.000000
# 25%           0.000000    0.000000   45490.000000   54940.500000   11.000000
# 50%           0.000000    1.000000   63494.000000   78052.500000   19.000000
# 75%           2.000000    1.000000   89090.000000  111019.500000   26.000000
# max           8.000000    3.000000  441990.000000  377798.000000   57.000000
#
#        star_rating       ratings      reviews
# count   896.000000    896.000000   896.000000
# mean      2.980469    367.391741    46.152902
# std       1.965254   1106.309355   136.079586
# min       0.000000      0.000000     0.000000
# ...

# %%
file.processor_name.unique()
# Out:
# array(['A6-9225 Processor', 'APU Dual', 'Athlon Dual', 'Core i3',
#        'Core i5', 'Celeron Dual', 'Ryzen', 'Ryzen 5', 'Core', 'Core i7',
#        'Core i9', 'Core m3', 'Dual Core', 'M1', 'Pentium Quad',
#        'Pentium Silver', 'Ryzen 3', 'MediaTek Kompanio', 'Quad',
#        'Ryzen 7', 'Ryzen 9', 'Snapdragon 7c'], dtype=object)

# %%
file.isnull().sum()
# Out:
# brand              0
# model              0
# processor_brand    0
# processor_name     0
# processor_gnrtn    0
# ram_gb             0
# ram_type           0
# ssd                0
# hdd                0
# os                 0
# os_bit             0
# graphic_card_gb    0
# weight             0
# display_size       0
# warranty           0
# Touchscreen        0
# msoffice           0
# latest_price       0
# old_price          0
# discount           0
# star_rating        0
# ratings            0
# reviews            0
# dtype: int64

# %%
#No. of Duplicate values
file.duplicated().sum()
# Out:
# 20

# %%
#Dropping Duplicated Records
file=file.drop_duplicates(keep='last')

# %%
file.duplicated().sum()
# Out:
# 0

# %%
file.nunique()
# Out:
# brand               21
# model              117
# processor_brand      5
# processor_name      22
# processor_gnrtn      8
# ram_gb               4
# ram_type             6
# ssd                  8
# hdd                  4
# os                   3
# os_bit               2
# graphic_card_gb      5
# weight               3
# display_size        16
# warranty             4
# Touchscreen          2
# msoffice             2
# latest_price       429
# old_price          564
# discount            48
# star_rating         30
# ratings            310
# reviews            152
# dtype: int64

# %% [markdown]
# ## Missing Values
#
# We have seen that there are no null values present in the dataset. But this doesn't mean there are no missing values in the dataset , since it can be represented in other means also.
#
# We'll check that.

# %%
for column in file.columns:
    print(column,(file[column]=='Missing').sum())
# Out:
# brand 0
# model 95
# processor_brand 0
# processor_name 0
# processor_gnrtn 238
# ram_gb 0
# ram_type 0
# ssd 0
# hdd 0
# os 0
# os_bit 0
# graphic_card_gb 0
# weight 0
# display_size 328
# warranty 0
# Touchscreen 0
# msoffice 0
# latest_price 0
# old_price 0
# discount 0
# star_rating 0
# ratings 0
# reviews 0

# %%
file=file.replace('Missing',np.nan)

# %% [markdown]
# # Univariate Analysis

# %%
sns.distplot(file['latest_price'])
plt.show()
# Out:
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5))
sns.distplot(file['old_price'],label='Old Price',hist=False)
sns.distplot(file['latest_price'],label='New Price',hist=False)
plt.title('KDE of New and Old Price')
plt.legend()
# Out:
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see in the above Distplot and KDE plot that laptop models with prices between fifty thousand and ninety thousand are having high density. According to the KDE plot, the densities of the latest prices are much higher than those of the old prices in the same price segment. Therefore, based on the above results, companies need to focus more on that price segment. Since the laptop market is primarily for students and professionals, companies should focus on laptops with suitable specifications for them. Using the same data set, let's look at different graphs to illustrate all of the facts about the laptop market.

# %%
categorical_features=['brand',  'processor_name',
       'processor_gnrtn', 'ram_gb', 'ram_type', 'ssd', 'hdd',
       'graphic_card_gb', 'weight', 'display_size', 'warranty', 'Touchscreen',
       'msoffice', 'discount', 'star_rating']

# %%
i=1
plt.figure(figsize = (15,25))
for feature in categorical_features:
  fig, ax1 = plt.subplots(figsize=(12,6))
  graph = sns.countplot(ax=ax1,x = feature , data = file,palette='pastel')
  graph.set_xticklabels(graph.get_xticklabels(),rotation=90)
  for p in graph.patches:
    height = p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1,height ,ha="center")
  i+=1

# %% [markdown]
# Let's analyze the obtained graphs.
#
# The largest number of laptops are produced under the brands ASUS, DELL, HP, Lenovo. Our data does not include quantitative notebook sales data, so a full market analysis is not possible.
#
# The mode of the display_size variable is 15.6, indicating high buyer demand. This is due to the fact that these laptops are used both at work and at home.
#
# The most common processors are Intel processors, especially Core i5, Core i7, Core i3. This phenomenon can be explained by low price and high performance.
# In the ram_gb variable, the value of 8 Gb is the mode. This means that this amount of memory is enough for most tasks. Demand creates supply:) *Most laptops are sold with an SSD drive. Many manufacturers, in an effort to win in the competition, save on additional slots in laptops by installing only one storage device. Choosing such a model, for example, with a fast SSD, you risk being left without a system and without personal data. The option with one HDD is also not very preferable, because. This type of media today demonstrates very low data exchange rates. Your system will be slow to boot, and applications will be annoying with the slowness of launching and processing data. Therefore, when choosing a device, give preference to the SSD + HDD dual disk system.
# The most common operating system value is Windows 64-bit. This can be explained by the simplicity and cheapness of using this system, as well as a much more extended distribution of programs.
# Gaming laptops are not popular because for games, stationary computers are used, in which the equipment is much more powerful.
# To compare continuous variables, we use the correlation matrix. It will also include some categorical variables

# %%
file.processor_brand.value_counts(normalize=True).plot.pie()
# Out:
# C:\Users\MY PC\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1616: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# <AxesSubplot:ylabel='processor_brand'>

# %%
os_count= file["os"].value_counts()
os_index = file["os"].value_counts().index

# %%
fig = plt.figure(figsize =(13, 6))
plt.pie(os_count, labels = os_index)

plt.show()

# %%
file.processor_brand.unique()
# Out:
# array(['AMD', 'Intel', 'M1', 'MediaTek', 'Qualcomm'], dtype=object)

# %% [markdown]
# Which are the available models under each brand ?

# %%
pd.set_option('display.max_colwidth',None)
models=file.groupby('brand').agg({'model':lambda x: set(x)})
models
# Out:
#                                                                                                                                                                                                model
# brand
# ALIENWARE                                                                                                                                                                                      {nan}
# APPLE                                                                                                                                                                                      {MacBook}
# ASUS       {nan, Pro, VivoBook14, Commercial, ROG, Pentium, ExpertBook, Intel, Ryzen, Vivo, EeeBook, Zenbook, Rog, ASUS, Celeron, AMD, F17, VivoBook, ZenBook, APU, TUF, Chromebook, Asus, Zephyrus}
# ...

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.scatterplot(x=file['star_rating'], y=file['latest_price'])
# Out:
# <AxesSubplot:xlabel='star_rating', ylabel='latest_price'>

# %% [markdown]
# There are a large number of plots above 3.5 rating in the plot above, ranging from fifty thousand to one lakh thirty thousand. In addition, laptops under 50,000 with a low budget have low ratings. For companies to capture good markets, these segments need to be reviewed and unnecessary features must be removed and performance must be improved based on usage.

# %%
top10 = file.nlargest(10,'latest_price')
plt.figure(figsize=(20,8))
plt.bar(top10['brand'], top10['latest_price'],color='gold',alpha=0.6)
plt.ylabel('Price', fontsize = 10)
plt.xlabel("Brand", fontsize = 10)
plt.title("Top 10 Expensive Laptop Brands", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Top 10 Expensive Laptop Brands')

# %%
top10 =file.nsmallest(10,'latest_price')
plt.figure(figsize=(20,8))
plt.bar(top10['brand'], top10['latest_price'],color='brown',alpha=0.2)
plt.ylabel('Price', fontsize = 10)
plt.xlabel("Brand", fontsize = 10)
plt.title("Top 10 Cheap Laptop Models", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Top 10 Cheap Laptop Models')

# %% [markdown]
# Which is the top reviewed Brand by the customer ?

# %%
plt.figure(figsize=(10,5))
file.groupby('brand').star_rating.mean().sort_values(ascending=False).plot(kind='bar')
plt.show()

# %% [markdown]
# According to this bar chart, Apple is the most popular brand, followed by Realme and Alienware However, brands like Realme, Nokia, Mi, Infinix, and etc., which are new to this market, are holding good ratings because they have fewer models and good features.
#  Many of the competitors, including Dell, HP, Lenovo, ASUS, and other brands, have a lot of models from low end to high end, so they have a bit low rating due to these models being low quality. In order to overcome this, they must focus on the segments with low ratings and improve their products.

# %%
file[['brand','latest_price']].groupby('brand').mean().sort_values(by='latest_price', ascending = False).head(11).plot(kind = 'barh', grid = True, figsize = (20,8), 
        fontsize = 15, rot =0, legend = None)
plt.axvline(file['latest_price'].mean(), color='r', linestyle='dashed', linewidth=3,label='the mean')
plt.xlabel('Price', fontsize = 15)
plt.ylabel('Brand', fontsize = 15)
plt.title("prices", fontsize = 15)
plt.show()

# %% [markdown]
# From this bar chart, we can find that Apple is the customer's favorite brand which is followed by Realme

# %% [markdown]
# ### What are the factors affecting the price of a laptop

# %%
plt.figure(figsize=(18,8))
sns.boxplot(x=file['ram_gb'],y=file['latest_price'])
plt.ylabel("latest_price")
plt.show()

# %% [markdown]
# From the boxplot it can be observed that the price of the laptop increases with the ram size. The top variant which is of 32 GB Ram size is in a price range between Rs.1 Lakh to Rs.2.4 Lakhs. We can also observe there are some outliers in the 8 GB and 4 GB variants

# %%
plt.figure(figsize=(18, 11))
sns.boxplot(x=file['hdd'], y=file['latest_price'])
plt.show()

# %%
plt.figure(figsize=(18, 11))
sns.boxplot(x=file['ssd'], y=file['latest_price'])
plt.show()

# %% [markdown]
# •	A laptop with 1TB HDD is priced below 60000 in the above first graph, with a few outliers.
# •	A laptop with 512 GB HDDs has a low budget, while a laptop with the same specs but a higher price has a combination of HDDs and SSDs.
# •	For laptops having 0gb HDD prices are high because they must be having SSD . as prices of SSD are high it effect the price of laptop.
# •	In case of ssd the prices are increasing as the size of the SSD increases.

# %%
sns.violinplot(x=file.warranty,y=file.latest_price)
plt.show()

# %% [markdown]
# From the given violin plot, we can observe that - as the warranty years increase the price also increases.

# %%
plt.figure(figsize=(18,10))
plt.title('Rating vs Price', fontweight='bold')
sns.scatterplot(x='star_rating', y='latest_price', hue='brand',s=200, data=file)
sns.despine(top=True, right=True)
plt.xlabel('Rating', fontweight='bold')
plt.ylabel('Price (USD)', fontweight='bold')
# Out:
# Text(0, 0.5, 'Price (USD)')

# %%
plt.figure(figsize=(18,10))
plt.title('Rating vs Price', fontweight='bold')
sns.scatterplot(x='star_rating', y='latest_price', hue='ssd',s=100, data=file)
sns.despine(top=True, right=True)
plt.xlabel('Rating', fontweight='bold')
plt.ylabel('Price (USD)', fontweight='bold')
# Out:
# Text(0, 0.5, 'Price (USD)')

# %% [markdown]
# In the above plot we can see that laptop with 512 ssd is having good rating for price ranging from 60000 to 100000 Companies like Apple uses only ssd for fast functioning of there laptops. The flash memory inside an SSD means data is written, transferred, and erased electronically and silently — SSDs don't have the moving parts found inside mechanical hard-disk drives (HDDs).

# %%
plt.figure(figsize=(18,10))
plt.title('Rating vs Price', fontweight='bold')
sns.scatterplot(x='star_rating', y='latest_price', hue='hdd',s=100, data=file)
sns.despine(top=True, right=True)
plt.xlabel('Rating', fontweight='bold')
plt.ylabel('Price (USD)', fontweight='bold')
# Out:
# Text(0, 0.5, 'Price (USD)')

# %% [markdown]
# According to this plot, laptops with 0 GB have a good rating and a good price, but this does not mean it does not have hard drive. Since it has a SSD, users find their PCs to be fast, so the ratings are a bit high.

# %%
plt.figure(figsize=(10,6))
plt.title('Rating vs Price', fontweight='bold')
sns.scatterplot(x='ratings', y='latest_price', hue='ssd', data=file)
sns.despine(top=True, right=True)
plt.xlabel('Rating', fontweight='bold')
plt.ylabel('Price (USD)', fontweight='bold')
# Out:
# Text(0, 0.5, 'Price (USD)')

# %%
plt.figure(figsize=(10,6))
plt.title('Rating vs Price', fontweight='bold')
sns.scatterplot(x='ratings', y='latest_price', hue='hdd', data=file)
sns.despine(top=True, right=True)
plt.xlabel('Rating', fontweight='bold')
plt.ylabel('Price (USD)', fontweight='bold')
# Out:
# Text(0, 0.5, 'Price (USD)')

# %%
plt.figure(figsize=(18,8))
file.groupby('processor_brand').star_rating.mean().sort_values(ascending=False).plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=file['old_price'],x=file['brand'],color='red',label='Old Price')
sns.barplot(y=file['latest_price'],x=file['brand'],color='yellow',label='New Price')
plt.xticks(rotation=90)
plt.title('Old vs New Price Comparision')
plt.legend( ncol=2, facecolor='gray', edgecolor='#f6f5f5', loc='upper left', fontsize=16)
plt.show()

# %%
sns.pairplot(file)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(file.corr(),annot=True)
plt.show()

# %%
correlation = file.corr()
print(correlation['latest_price'].sort_values(ascending = False),'\n')
# Out:
# latest_price       1.000000
# old_price          0.744950
# graphic_card_gb    0.494891
# warranty           0.034402
# star_rating       -0.172905
# ratings           -0.174766
# reviews           -0.175564
# discount          -0.207282
# Name: latest_price, dtype: float64

# %%
k= 10
cols = correlation.nlargest(k,'latest_price')['latest_price'].index
print(cols)
cm = np.corrcoef(file[cols].values.T)
mask = np.triu(np.ones_like(file.corr()))
f , ax = plt.subplots(figsize = (14,12))
sns.heatmap(cm,mask=mask, vmax=.8, linewidths=0.01,square=True,annot=True,cmap='YlGnBu',
            linecolor="white",xticklabels = cols.values ,annot_kws = {'size':12},yticklabels = cols.values)
# Out:
# Index(['latest_price', 'old_price', 'graphic_card_gb', 'warranty',
#        'star_rating', 'ratings', 'reviews', 'discount'],
#       dtype='object')
# <AxesSubplot:>

# %% [markdown]
# Conclusions from the construction of the correlation matrix:
# •	the old and new prices correlate, this is not surprising :) In the future, to predict the price of a laptop, it is proposed to delete the value of the old price *price is largely dependent on the memory capacity of the graphics card.
# •	rating and reviews are very strongly correlated and are duplicate information, it is proposed to remove the reviews.

# %% [markdown]
# Conclusion
# Laptop costs play a decisive role for many, while other factors are overlooked. As a result — regrets after the first days of operation. At the same time, even a famous brand and a high price do not guarantee that you will get what really suits you. It is common for users to compromise, even when they have a lot of choices, as long as a few or three important parameters match.
# Therefore, first of all, it is worth deciding for what purpose you are purchasing a laptop. This will depend on the size and resolution of the screen, the processor, video card and the amount of RAM.
# •	The most common problem statement is a machine for working with documents, multimedia and surfing the Internet. For these purposes, a CPU with average performance and an integrated video card is suitable. When choosing a model, many users are guided by the low price of the device, losing sight of the fact that the computer has an outdated processor with low efficiency.
# •	At first, the weak heart of the computer will demonstrate acceptable speed in office applications and when surfing the net. However, as soon as Windows runs an update in the background, a virus scan, or simply copying files to an external drive, the machine will turn into a prehistoric turtle.
# •	 The Intel Core i5 and i7 CPU models will allow you to have some margin in computing power - they are used in powerful workstations and gaming mobile PCs. Also, on sale you can find laptops with Ryzen 5 processors from AMD, which have good integrated graphics on board, which is approximately on par with the GT 1030.
# •	Recently, manufacturers have been actively exploiting the trend of screens with 4K resolution (3840 × 2160). In our opinion, it is a mistake to succumb to marketing traps and pay attention to such offers in portable devices. The fact is that the human eye already has difficulty distinguishing pixels on a 23-inch monitor with Full HD resolution from a distance of 40 cm. At 17 or 15 inches, you definitely won’t feel an increase in image quality. At the same time, a 4K monitor will show too small elements of the Windows interface and programs, which will only cause discomfort.
# •	 It should be borne in mind that a more detailed display of graphics in 4K takes resources from the video card and CPU. Therefore, the best screen resolution for a laptop is 1920x1080. If you want more, connect your computer to a large UHD monitor and enjoy an ultra-detailed picture on it.
# •	Many manufacturers, in an effort to win in the competition, save on additional slots in laptops by installing only one storage device. Choosing such a model, for example, with a fast SSD, you risk being left without a system and without personal data.
# •	The option with one HDD is also not very preferable, because. This type of media today demonstrates very low data exchange rates. Your system will be slow to boot, and applications will be annoying with the slowness of launching and processing data. Therefore, when choosing a device, give preference to the SSD + HDD dual disk system.
# •	For office work and surfing the Web, it is desirable to have at least 4 GB of RAM. For graphics and games, 8 GB is enough. Complex tasks may require 16 or even 32 GB of RAM. In the latter case, it is important to have both a very productive and expensive CPU. Before buying, ask how the memory is installed - one module or two equal parts, i.e. in dual-channel mode, which somewhat speeds up data processing.
